# %% [raw]
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
# It also provides support for advanced statistical analysis, such as regression analysis, distribution plots, and categorical plots.
# Seaborn's key benefit lies in its capability to generate attractive plots with minimal coding efforts
# It provides a range of default themes and color palettes, which you can easily customize to suit your preferences.

# %% [raw]
# Seaborn is generally better suited for creating statistical graphics and exploratory data analysis, while Matplotlib is better suited for creating highly customizable plots for presentations and publications

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('iris')

sns.lineplot(x = "sepal_length", y = 'sepal_width', data =data)
# sns.set_style("darkgrid")
# sns.despine()

# plt.title("This is title using Matplolib")
# plt.xlim(5)
# plt.ylim(3)
plt.figure(figsize=(8,6))

plt.show()

# %%
tips = sns.load_dataset("tips")
sns.histplot(x = "total_bill", data = tips, bins=50)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
exercise = sns.load_dataset('exercise')
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %% [markdown]
# # Seaborn Plot types
# Seaborn provides a wide range of plot types that can be used for data visualization and exploratory data analysis. Broadly speaking, any visualization can fall into one of the three categories.
#
# Univariate – x only (contains only one axis of information)
#
#
# Bivariate – x and y (contains two axis of information)
#
#
# Trivariate – x, y, z (contains three axis of information)

# %% [raw]
# Here are some of the most commonly used plot types in Seaborn:
#
# Scatter Plot. A scatter plot is used to visualize the relationship between two variables. Seaborn's scatterplot() function provides a simple way to create scatter plots.
#
# Line Plot. A line plot is used to visualize the trend of a variable over time. Seaborn's lineplot() function provides a simple way to create line plots.
#
# Histogram. A histogram is used to visualize the distribution of a variable. Seaborn's histplot() function provides a simple way to create histograms.
#
# Box Plot. A box plot is used to visualize the distribution of a variable. Seaborn's boxplot() function provides a simple way to create box plots.
#
# Violin Plot. A violin plot is similar to a box plot, but provides a more detailed view of the distribution of the data. Seaborn's violinplot() function provides a simple way to create violin plots.
#
# Heatmap. A heatmap is used to visualize the correlation between different variables. Seaborn's heatmap() function provides a simple way to create heatmaps.
#
# Pairplot. A pairplot is used to visualize the relationship between multiple variables. Seaborn's pairplot() function provides a simple way to create pairplots.

# %% [markdown]
# # Seaborn scatter plots

# %%
sns.scatterplot(x= "total_bill", y = "tip",data = tips, palette='Set2',hue ='day' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(11,5))
sns.scatterplot(x = "total_bill", y = "tip", data = tips , hue ="sex", size = "size", sizes= (50,200))
plt.xlabel('Total Bill')
plt.ylabel('Tips')
plt.title("Relatioship between total bill and tip")

plt.show()

# %% [markdown]
# # Seaborn line plots

# %%
fmri = sns.load_dataset('fmri')
sns.lineplot(x = "timepoint", y = 'signal', data = fmri,
             hue = 'event', 
            style = 'region',
            markers = True,
            dashes=False)

plt.xlabel("timeout")
plt.ylabel("signal")
plt.title("Changes in Signal Intensity over Time")
plt.show()

# %% [markdown]
# # Seaborn bar plots

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x ='class', y = 'fare', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x = 'class', y = 'fare', data = titanic, hue = 'sex',ci =None, palette="muted")

plt.xlabel("Class")
plt.ylabel("Fare")
plt.title("Average Fare by Class and Gender on the Titanic")
# Out:
# C:\Users\Ajay Patil\AppData\Local\Temp\ipykernel_35860\772003267.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'class', y = 'fare', data = titanic, hue = 'sex',ci =None, palette="muted")
# Text(0.5, 1.0, 'Average Fare by Class and Gender on the Titanic')

# %% [markdown]
# # Seaborn histograms

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(x = 'petal_length', data = iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
#kde specifies whether to include a kernel density estimate,
sns.histplot(x= 'petal_length', data = iris, bins = 50,kde =True, color = 'green')

plt.xlabel('petal length in cm')
plt.ylabel('Frequency')
plt.title('Distribution of petal length in iris flower')
# Out:
# Text(0.5, 1.0, 'Distribution of petal length in iris flower')

# %% [markdown]
# # Seaborn density plots
#
# Density plots, also known as kernel density plots, are a type of data visualization that display the distribution of a continuous variable. They are similar to histograms, but instead of representing the data as bars, density plots use a smooth curve to estimate the density of the data. In Seaborn, density plots can be created using the kdeplot() function.

# %%
sns.kdeplot(x = "petal_length", data = iris,color ='green')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.kdeplot(x = 'total_bill', data =tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x = 'total_bill', data = tips, hue = "time", fill = True, alpha = 0.6, linewidth = 1.5)
plt.xlabel("total bill")
plt.ylabel("density")   
plt.title("Density plot of Total meal by meal time")
plt.show()

# %% [markdown]
# # Seaborn box plots

# %%
sns.boxenplot(x = "day", y ="total_bill", data =tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue ='time', palette='Set3', linewidth = 1.5, fliersize = 4)

plt.xlabel('Day of week ')
plt.ylabel('Total Bill')
plt.title('Box plot of total bill and meal time')

plt.show()

# %% [markdown]
# # Seaborn violin plots
#
# A violin plot is a type of data visualization that combines aspects of both box plots and density plots.
#
# It displays a density estimate of the data, usually smoothed by a kernel density estimator, along with the interquartile range (IQR) and median in a box plot-like form.
#
# The width of the violin represents the density estimate, with wider parts indicating higher density, and the IQR and median are shown as a white dot and line within the violin.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.violinplot(x = "species", y = "petal_length", data = iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Seaborn heatmaps
#
# A heatmap is a graphical representation of data that uses colors to depict the value of a variable in a two-dimensional space. Heatmaps are commonly used to visualize the correlation between different variables in a dataset.
#
#  cmap parameter set to 'Blues' to specify the color scheme, annot parameter set to True to display the data values on the heatmap, and fmt parameter set to 'd' to format the data values as integers.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
correlation = tips.corr()
sns.heatmap(correlation, annot=True)
# Out:
# C:\Users\Ajay Patil\AppData\Local\Temp\ipykernel_35860\2771308724.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = tips.corr()
# <Axes: >

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flights_pivot = flights.pivot('month','year','passengers')
sns.heatmap(flights_pivot, cmap = 'Blues', annot=True, fmt ='d')

plt.xlabel('Year')
plt.ylabel('Month')
plt.title("Passenger per month")
plt.figure(figsize= (25,6))
plt.savefig("heatmap.png",transparent=True )
plt.show()
# Out:
# C:\Users\Ajay Patil\AppData\Local\Temp\ipykernel_35860\295760937.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_pivot = flights.pivot('month','year','passengers')

# %% [markdown]
# # Seaborn pair plots
#
# Pair plots are a type of visualization in which multiple pairwise scatter plots are displayed in a matrix format. Each scatter plot shows the relationship between two variables, while the diagonal plots show the distribution of the individual variables.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,)

plt.grid()
plt.show()

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(data = iris, hue = 'species', diag_kind= "hist", palette='husl') #diag_king = 'auto', 'hist','kde', 'NOne'

# %% [markdown]
# # Seaborn joint plots
#
# joint plot is a powerful visualization technique in seaborn that combines two different plots in one visualization: a scatter plot and a histogram.

# %%
iris.head()
# print(iris['sepal_length'].max())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.jointplot(data = iris, x ='sepal_length', y= 'sepal_width')

# %% [markdown]
# # Seaborn facet grids
#
# FacetGrid is a powerful seaborn tool that allows you to visualize the distribution of one variable as well as the relationship between two variables, across levels of additional categorical variables.
#
# FacetGrid creates a grid of subplots based on the unique values in the categorical variable specified.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col ='day')
g.map(sns.histplot, "total_bill")

# %%
g = sns.FacetGrid(tips, col ="time")
g.map(sns.barplot, 'total_bill','tip')
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # PIe chart

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a list of data
data = [44, 45, 40, 41, 39]

# Create a pie chart of the data
plt.pie(data, labels=["A", "B", "C", "D", "E"], autopct="%1.1f%%")

# Display the pie chart
plt.show()

# %% [markdown]
# # Best practices for Seaborn visualization

# %% [raw]
# 1.Choose the right plot type for your data
# 2.Use color effectively ***
# 3.Label your axes and use clear titles
# 4.Consider the audience (business Insights must be there)
